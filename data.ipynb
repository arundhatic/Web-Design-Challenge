# %%
import pandas as pd

# %%
data_path = "Resources/cities.csv"
data_df = pd.read_csv(data_path)

# %%
data_df.head()
# Out:
#    Unnamed: 0          City  Cloudiness Country        Date  Humidity    Lat  \
# 0           0  saint george          90      GR  1576713639        93  39.45
# 1           1    butaritari           0      KI  1576713640        78   3.07
# 2           2      smithers          90      CA  1576713490        97  54.78
# 3           3     cape town          40      ZA  1576713615        77 -33.93
# 4           4        pangoa         100      PE  1576713644        97 -12.12
#
#       Lng  Max Temperature  Wind Speed
# 0   22.34            10.00        2.60
# 1  172.79            28.93        4.66
# 2 -127.17             0.00        2.10
# 3   18.42            17.22        4.60
# 4  -73.00            20.87        0.17

# %%
data_df.to_html('cities.html')

# %%
# OSX Users can run this to open the file in a browser, 
# or you can manually find the file and open it in the browser
# !open cities.html

# %%
data_df.rename({'Unnamed: 0': 'city_id'}, axis=1, inplace=True)

# %%
data_df.head()
# Out:
#    city_id          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  saint george          90      GR  1576713639        93  39.45
# 1        1    butaritari           0      KI  1576713640        78   3.07
# 2        2      smithers          90      CA  1576713490        97  54.78
# 3        3     cape town          40      ZA  1576713615        77 -33.93
# 4        4        pangoa         100      PE  1576713644        97 -12.12
#
#       Lng  Max Temperature  Wind Speed
# 0   22.34            10.00        2.60
# 1  172.79            28.93        4.66
# 2 -127.17             0.00        2.10
# 3   18.42            17.22        4.60
# 4  -73.00            20.87        0.17

# %%
data_df.to_html('cities.html')

# %%
# OSX Users can run this to open the file in a browser, 
# or you can manually find the file and open it in the browser
# !open cities.html
